# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
# %matplotlib inline

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111,projection='3d')
plt.show()

# %%
g=np.loadtxt('datos.txt')

# %%
Px=g[:,0:1]
Py=g[:,1:2]
Pz=g[:,2:3]

# %%
print(Px)
# Out:
# [[ -12.]
#  [  15.]
#  [  28.]
#  [  32.]
#  [  14.]
#  [-145.]
#  [ -26.]
#  [  20.]
#  [  15.]
#  [  28.]
#  [  32.]
#  [  14.]
#  [ 145.]
#  [  26.]
#  [  23.]
#  [ -15.]]

# %%
Px1=Px.T
print(Px1)
# Out:
# [[ -12.   15.   28.   32.   14. -145.  -26.   20.   15.   28.   32.   14.
#    145.   26.   23.  -15.]]

# %%
print(g)
# Out:
# [[ -12.  -18.  -30.  556.   32.   12.]
#  [  15.   30.  -25.   25.    3.   32.]
#  [  28.   15.  254.    3.   20.   12.]
#  [  32.  -12.   54.   21.   35.   48.]
#  [  14.  -13.    5.   35.    5.   35.]
#  [-145.   23.   45.   41.   13.   13.]
#  [ -26.   23.   45.   32.   20.   15.]
#  [  20.   78.   84.   52.   32.   12.]
#  [  15.  -30.   25.   25.    3.   32.]
#  [  28.   15. -254.    3.   20.   12.]
#  [  32.   12.   54.   21.   35.   48.]
#  [  14.   13.    5.   35.    5.   35.]
#  [ 145.   23.   45.   41.   13.   13.]
#  [  26.   23.  -45.   32.   20.   15.]
#  [  23.   78.  -84.   52.   32.   12.]
#  [ -15.  -36.   23.   45.   48.   20.]]

# %%
g[0][3]
g[0]
# Out:
# array([-12., -18., -30., 556.,  32.,  12.])

# %%
plt.plot(g[0][0],g[0][1],'-o')

# %%
print (g[0][0], g[0][1], g[0][2])
# Out:
# -12.0 -18.0 -30.0

# %%
print (g)
# Out:
# [[ -12.  -18.  -30.  556.   32.   12.]
#  [  15.   30.  -25.   25.    3.   32.]
#  [  28.   15.  254.    3.   20.   12.]
#  [  32.  -12.   54.   21.   35.   48.]
#  [  14.  -13.    5.   35.    5.   35.]
#  [-145.   23.   45.   41.   13.   13.]
#  [ -26.   23.   45.   32.   20.   15.]
#  [  20.   78.   84.   52.   32.   12.]
#  [  15.  -30.   25.   25.    3.   32.]
#  [  28.   15. -254.    3.   20.   12.]
#  [  32.   12.   54.   21.   35.   48.]
#  [  14.   13.    5.   35.    5.   35.]
#  [ 145.   23.   45.   41.   13.   13.]
#  [  26.   23.  -45.   32.   20.   15.]
#  [  23.   78.  -84.   52.   32.   12.]
#  [ -15.  -36.   23.   45.   48.   20.]]

# %%
e=g.T
print (e)
# Out:
# [[ -12.   15.   28.   32.   14. -145.  -26.   20.   15.   28.   32.   14.
#    145.   26.   23.  -15.]
#  [ -18.   30.   15.  -12.  -13.   23.   23.   78.  -30.   15.   12.   13.
#     23.   23.   78.  -36.]
#  [ -30.  -25.  254.   54.    5.   45.   45.   84.   25. -254.   54.    5.
#     45.  -45.  -84.   23.]
#  [ 556.   25.    3.   21.   35.   41.   32.   52.   25.    3.   21.   35.
#     41.   32.   52.   45.]
#  [  32.    3.   20.   35.    5.   13.   20.   32.    3.   20.   35.    5.
#     13.   20.   32.   48.]
#  [  12.   32.   12.   48.   35.   13.   15.   12.   32.   12.   48.   35.
#     13.   15.   12.   20.]]

# %%
x = np.array(e[[0]])
y = np.array(e[[1]])
z = np.array(e[[2]]) 
fig = plt.figure()
ax1 = fig.add_subplot(111,projection = '3d')
ax1.scatter(Px,Py,Pz, c='g',marker='o')
plt.show()

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111,projection = '3d')
ax1.scatter(x,y,z, c='r',marker='o')
plt.show()

# %%
g
# Out:
# array([[ -12.,  -18.,  -30.,  556.,   32.,   12.],
#        [  15.,   30.,  -25.,   25.,    3.,   32.],
#        [  28.,   15.,  254.,    3.,   20.,   12.],
#        [  32.,  -12.,   54.,   21.,   35.,   48.],
#        [  14.,  -13.,    5.,   35.,    5.,   35.],
#        [-145.,   23.,   45.,   41.,   13.,   13.],
#        [ -26.,   23.,   45.,   32.,   20.,   15.],
#        [  20.,   78.,   84.,   52.,   32.,   12.],
#        [  15.,  -30.,   25.,   25.,    3.,   32.],
#        [  28.,   15., -254.,    3.,   20.,   12.],
#        [  32.,   12.,   54.,   21.,   35.,   48.],
#        [  14.,   13.,    5.,   35.,    5.,   35.],
#        [ 145.,   23.,   45.,   41.,   13.,   13.],
#        [  26.,   23.,  -45.,   32.,   20.,   15.],
#        [  23.,   78.,  -84.,   52.,   32.,   12.],
#        [ -15.,  -36.,   23.,   45.,   48.,   20.]])

# %%
b=g[0:8]
c=g[8:16]

# %%
print(b)
print(c)
# Out:
# [[ -12.  -18.  -30.  556.   32.   12.]
#  [  15.   30.  -25.   25.    3.   32.]
#  [  28.   15.  254.    3.   20.   12.]
#  [  32.  -12.   54.   21.   35.   48.]
#  [  14.  -13.    5.   35.    5.   35.]
#  [-145.   23.   45.   41.   13.   13.]
#  [ -26.   23.   45.   32.   20.   15.]
#  [  20.   78.   84.   52.   32.   12.]]
# [[  15.  -30.   25.   25.    3.   32.]
#  [  28.   15. -254.    3.   20.   12.]
#  [  32.   12.   54.   21.   35.   48.]
#  [  14.   13.    5.   35.    5.   35.]
#  [ 145.   23.   45.   41.   13.   13.]
#  [  26.   23.  -45.   32.   20.   15.]
#  [  23.   78.  -84.   52.   32.   12.]
#  [ -15.  -36.   23.   45.   48.   20.]]

# %%
#for i in range(100):
g=np.loadtxt('0000.txt')
b=g[0:200]
c=g[200:500]
g1=b.T
g2=c.T
x = np.array(g1[[0]])
y = np.array(g1[[1]])
z = np.array(g1[[2]]) 
x1 = np.array(g2[[0]])
y1 = np.array(g2[[1]])
z1 = np.array(g2[[2]]) 
fig = plt.figure()
ax1 = fig.add_subplot(111, projection='3d')
ax1.scatter(x, y, z, c='g', marker='o')
ax1.scatter(x1, y1, z1, c ='r', marker='o')

# %%
T=np.loadtxt('tamaño1.txt')
n1=np.array(T[0])
n2=np.array(T[1])
n11=int(n1)
n22=int(n2)
g=np.loadtxt('0101.txt')
b=g[0:n11]
c=g[n11+1:n11+n22]
g1=b.T
g2=c.T
x = np.array(g1[[0]])
y = np.array(g1[[1]])
z = np.array(g1[[2]]) 
x1 = np.array(g2[[0]])
y1 = np.array(g2[[1]])
z1 = np.array(g2[[2]]) 
fig = plt.figure()
ax1 = fig.add_subplot(111, projection='3d')
ax1.scatter(x, y, z, c='g', marker='o')
ax1.scatter(x1, y1, z1, c ='r', marker='o')
